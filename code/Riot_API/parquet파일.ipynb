# %%
# 라이브러리 실행 확인용
import pandas as pd
import os

# %%
# details_kr_part1.parquet csv로 변환
import pandas as pd
import os

def view_and_save_with_absolute_path(input_path, output_path):
    """
    지정된 절대 경로의 Parquet 파일을 읽어 데이터를 확인하고 CSV로 저장하는 함수입니다.
    """
    # 1. 파일 존재 여부 확인
    if not os.path.exists(input_path):
        print(f"오류: 지정한 경로에 파일이 존재하지 않습니다. 경로를 다시 확인해주세요.\n{input_path}")
        return None
        
    try:
        print("데이터를 불러오는 중입니다. 잠시만 기다려주세요.")
        
        # 2. 데이터 불러오기
        df = pd.read_parquet(input_path, engine='pyarrow')
        
        # 3. 전체 열을 볼 수 있도록 옵션 설정
        pd.set_option('display.max_columns', None)
        
        # 4. 데이터 미리보기
        print("\n[데이터 미리보기]")
        display(df.head())
        print(f"\n총 데이터 크기: {df.shape[0]}행, {df.shape[1]}열")
        
        # 5. CSV 파일로 저장
        print("\n데이터를 CSV 파일로 저장하는 중입니다...")
        df.to_csv(output_path, index=False, encoding='utf-8-sig')
        
        print(f"저장 완료! 아래 경로에 CSV 파일이 생성되었습니다.\n{output_path}")
        
        return df
        
    except Exception as e:
        print(f"파일을 처리하는 도중 문제가 발생했습니다: {e}")
        return None

# 알려주신 원본 파일의 절대 경로 (문자열 앞에 r을 붙여 백슬래시 오류 방지)
file_path = r"D:\바탕화면\데이터 분석\프로젝트\04 최종 프로젝트\구글 드라이브\details_kr_part1.parquet"

# 저장할 CSV 파일의 절대 경로 (동일한 폴더, 확장자만 csv로 변경)
csv_path = r"D:\바탕화면\데이터 분석\프로젝트\04 최종 프로젝트\구글 드라이브\details_kr_part1.csv"

# 함수 실행
kr_data = view_and_save_with_absolute_path(file_path, csv_path)
# Out:
# 데이터를 불러오는 중입니다. 잠시만 기다려주세요.
#
# [데이터 미리보기]
#                                             metadata  \
# 0  {'dataVersion': '2', 'matchId': 'KR_7732890911...
# 1  {'dataVersion': '2', 'matchId': 'KR_8006003717...
# 2  {'dataVersion': '2', 'matchId': 'KR_7535288608...
# 3  {'dataVersion': '2', 'matchId': 'KR_8068731228...
# 4  {'dataVersion': '2', 'matchId': 'KR_7023419356...
#
#                                                 info
# 0  {'endOfGameResult': 'GameComplete', 'gameCreat...
# 1  {'endOfGameResult': 'GameComplete', 'gameCreat...
# 2  {'endOfGameResult': 'GameComplete', 'gameCreat...
# 3  {'endOfGameResult': 'GameComplete', 'gameCreat...
# 4  {'endOfGameResult': 'GameComplete', 'gameCreat...
# 총 데이터 크기: 23523행, 2열
#
# 데이터를 CSV 파일로 저장하는 중입니다...
# 저장 완료! 아래 경로에 CSV 파일이 생성되었습니다.
# D:\바탕화면\데이터 분석\프로젝트\04 최종 프로젝트\구글 드라이브\details_kr_part1.csv

# %%
#위 결과 csv 파일에서 회의로 통해 나눈 컬럼만 뽑기
import pandas as pd
import numpy as np
import os

def process_full_parquet_to_csv_fixed(input_path, output_path, target_cols):
    if not os.path.exists(input_path):
        print(f"오류: 지정한 경로에 파일이 존재하지 않습니다.\n{input_path}")
        return None
        
    try:
        print("1. Parquet 파일 로드 중... (시간이 조금 걸릴 수 있습니다)")
        df_raw = pd.read_parquet(input_path, engine='pyarrow')
        total_matches = len(df_raw)
        print(f" -> 총 {total_matches}개의 매치(게임) 데이터를 성공적으로 불러왔습니다.\n")
        
        processed_rows = []
        print("2. 데이터 변환(평탄화) 작업을 시작합니다...")
        
        # 전체 매치를 한 줄씩 순회
        for index, row in df_raw.iterrows():
            if (index + 1) % 1000 == 0:
                print(f" -> 진행 중: {index + 1} / {total_matches} 매치 변환 완료")
                
            # 라이엇 API 구조 반영: metadata와 info 분리 확인
            # 데이터프레임의 최상단 컬럼이거나, 내부에 들어있을 경우 모두 대비
            metadata = row.get('metadata', {})
            info = row.get('info', {})
            
            # 자료형 안전 변환
            if pd.notnull(metadata) and not isinstance(metadata, dict):
                try: metadata = dict(metadata)
                except: metadata = {}
            if pd.notnull(info) and not isinstance(info, dict):
                try: info = dict(info)
                except: info = {}

            # 공통 데이터 추출
            common_info = {
                'dataVersion': metadata.get('dataVersion', row.get('dataVersion')),
                'matchId': metadata.get('matchId', row.get('matchId')),
                'endOfGameResult': info.get('endOfGameResult', row.get('endOfGameResult')),
                'gameCreation': info.get('gameCreation', row.get('gameCreation')),
                'gameDuration': info.get('gameDuration', row.get('gameDuration')),
                'gameVersion': info.get('gameVersion', row.get('gameVersion')),
                'queueId': info.get('queueId', row.get('queueId'))
            }
            
            # 참가자(participants) 정보는 info 안에 존재함
            participants = info.get('participants', row.get('participants', []))
            
            # numpy 배열 형태라면 리스트로 변환
            if isinstance(participants, np.ndarray):
                participants = participants.tolist()
                
            if not isinstance(participants, list):
                continue
                
            # 10명의 플레이어를 순회
            for p in participants:
                # pyarrow struct 데이터를 dict로 강제 변환
                if not isinstance(p, dict):
                    try: p = dict(p)
                    except: continue
                    
                player_row = {}
                challenges = p.get('challenges', {})
                if not isinstance(challenges, dict):
                    try: challenges = dict(challenges)
                    except: challenges = {}
                
                # 요청하신 타겟 컬럼에 맞춰 데이터 매핑
                for col in target_cols:
                    if col in common_info:
                        player_row[col] = common_info[col]
                    elif col.startswith('ch_'):
                        actual_key = col[3:]  # 'ch_' 제외한 원래 이름
                        player_row[col] = challenges.get(actual_key, None)
                    else:
                        player_row[col] = p.get(col, None)
                        
                processed_rows.append(player_row)
                
        print("\n3. 변환된 데이터를 DataFrame으로 조립하는 중...")
        final_df = pd.DataFrame(processed_rows, columns=target_cols)
        print(f" -> 최종 데이터 크기: {final_df.shape[0]}행(플레이어 수), {final_df.shape[1]}열")
        
        if final_df.shape[0] == 0:
            print("\n[경고] 추출된 데이터가 여전히 0행입니다.")
            print("데이터의 실제 컬럼명 구조 확인용 출력:")
            print(df_raw.columns.tolist())
            return final_df
        
        print(f"\n4. CSV 파일로 저장하는 중입니다...")
        final_df.to_csv(output_path, index=False, encoding='utf-8-sig')
        print(f" -> 저장 완료! 아래 경로에서 확인해주세요.\n{output_path}")
        
        return final_df
        
    except Exception as e:
        print(f"처리 도중 오류가 발생했습니다: {e}")
        return None

# ==========================================
# 실행을 위한 설정 영역
# ==========================================

target_columns = [
    "assists", "baronKills", "bountyLevel", "ch_abilityUses", "ch_acesBefore15Minutes",
    "ch_alliedJungleMonsterKills", "ch_baronBuffGoldAdvantageOverThreshold", "ch_baronTakedowns",
    "ch_bountyGold", "ch_buffsStolen", "ch_completeSupportQuestInTime", "ch_controlWardTimeCoverageInRiverOrEnemyHalf",
    "ch_controlWardsPlaced", "ch_damagePerMinute", "ch_damageTakenOnTeamPercentage", "ch_deathsByEnemyChamps",
    "ch_dragonTakedowns", "ch_earlyLaningPhaseGoldExpAdvantage", "ch_effectiveHealAndShielding", "ch_enemyChampionImmobilizations",
    "ch_enemyJungleMonsterKills", "ch_epicMonsterKillsWithin30SecondsOfSpawn", "ch_epicMonsterSteals", "ch_goldPerMinute",
    "ch_hadAfkTeammate", "ch_highestChampionDamage", "ch_highestCrowdControlScore", "ch_highestWardKills",
    "ch_immobilizeAndKillWithAlly", "ch_initialBuffCount", "ch_initialCrabCount", "ch_jungleCsBefore10Minutes",
    "ch_junglerKillsEarlyJungle", "ch_junglerTakedownsNearDamagedEpicMonster", "ch_kTurretsDestroyedBeforePlatesFall",
    "ch_kda", "ch_killParticipation", "ch_killingSprees", "ch_killsNearEnemyTurret", "ch_killsOnLanersEarlyJungleAsJungler",
    "ch_killsOnOtherLanesEarlyJungleAsLaner", "ch_killsUnderOwnTurret", "ch_knockEnemyIntoTeamAndKill", "ch_landSkillShotsEarlyGame",
    "ch_laneMinionsFirst10Minutes", "ch_laningPhaseGoldExpAdvantage", "ch_legendaryCount", "ch_maxCsAdvantageOnLaneOpponent",
    "ch_maxKillDeficit", "ch_maxLevelLeadLaneOpponent", "ch_mejaisFullStackInTime", "ch_moreEnemyJungleThanOpponent",
    "ch_multikills", "ch_outerTurretExecutesBefore10Minutes", "ch_playedChampSelectPosition", "ch_quickFirstTurret",
    "ch_quickSoloKills", "ch_riftHeraldTakedowns", "ch_saveAllyFromDeath", "ch_scuttleCrabKills", "ch_soloKills",
    "ch_stealthWardsPlaced", "ch_takedowns", "ch_takedownsAfterGainingLevelAdvantage", "ch_takedownsBeforeJungleMinionSpawn",
    "ch_takedownsFirstXMinutes", "ch_takedownsInEnemyFountain", "ch_teamBaronKills", "ch_teamDamagePercentage",
    "ch_teamElderDragonKills", "ch_teamRiftHeraldKills", "ch_turretPlatesTaken", "ch_turretTakedowns", "ch_turretsTakenWithRiftHerald",
    "ch_unseenRecalls", "ch_visionScoreAdvantageLaneOpponent", "ch_visionScorePerMinute", "ch_wardTakedowns",
    "ch_wardTakedownsBefore20M", "champExperience", "champLevel", "championName", "championTransform",
    "damageDealtToBuildings", "damageDealtToEpicMonsters", "damageDealtToObjectives", "damageDealtToTurrets",
    "damageSelfMitigated", "dataVersion", "deaths", "detectorWardsPlaced", "doubleKills", "eligibleForProgression",
    "endOfGameResult", "firstBloodAssist", "firstBloodKill", "firstTowerAssist", "firstTowerKill", "gameCreation",
    "gameDuration", "gameEndedInEarlySurrender", "gameEndedInSurrender", "gameVersion", "goldEarned", "goldSpent",
    "individualPosition", "inhibitorTakedowns", "inhibitorsLost", "itemsPurchased", "killingSprees", "kills",
    "magicDamageDealt", "magicDamageDealtToChampions", "magicDamageTaken", "matchId", "neutralMinionsKilled",
    "objectivesStolen", "objectivesStolenAssists", "participantId", "perks", "physicalDamageDealt", "physicalDamageDealtToChampions",
    "physicalDamageTaken", "queueId", "summonerId", "summonerLevel", "teamEarlySurrendered", "teamId", "teamPosition",
    "timeCCingOthers", "timePlayed", "totalAllyJungleMinionsKilled", "totalDamageDealt", "totalDamageDealtToChampions",
    "totalDamageShieldedOnTeammates", "totalDamageTaken", "totalEnemyJungleMinionsKilled", "totalHeal", "totalHealsOnTeammates",
    "totalMinionsKilled", "totalTimeCCDealt", "totalTimeSpentDead", "totalUnitsHealed", "trueDamageDealt",
    "trueDamageDealtToChampions", "trueDamageTaken", "turretKills", "turretTakedowns", "turretsLost", "visionScore",
    "visionWardsBoughtInGame", "wardsKilled", "wardsPlaced", "win"
]

file_path_in = r"D:\바탕화면\데이터 분석\프로젝트\04 최종 프로젝트\구글 드라이브\details_kr_part1.parquet"
file_path_out = r"D:\바탕화면\데이터 분석\프로젝트\04 최종 프로젝트\구글 드라이브\details_kr_part1_flattened.csv"

final_kr_data = process_full_parquet_to_csv_fixed(file_path_in, file_path_out, target_columns)

if final_kr_data is not None and final_kr_data.shape[0] > 0:
    pd.set_option('display.max_columns', 20)
    display(final_kr_data.head())
# Out:
# 1. Parquet 파일 로드 중... (시간이 조금 걸릴 수 있습니다)
#  -> 총 23523개의 매치(게임) 데이터를 성공적으로 불러왔습니다.
#
# 2. 데이터 변환(평탄화) 작업을 시작합니다...
#  -> 진행 중: 1000 / 23523 매치 변환 완료
#  -> 진행 중: 2000 / 23523 매치 변환 완료
#  -> 진행 중: 3000 / 23523 매치 변환 완료
#  -> 진행 중: 4000 / 23523 매치 변환 완료
#  -> 진행 중: 5000 / 23523 매치 변환 완료
#  -> 진행 중: 6000 / 23523 매치 변환 완료
#  -> 진행 중: 7000 / 23523 매치 변환 완료
#  -> 진행 중: 8000 / 23523 매치 변환 완료
#  -> 진행 중: 9000 / 23523 매치 변환 완료
#  -> 진행 중: 10000 / 23523 매치 변환 완료
#  -> 진행 중: 11000 / 23523 매치 변환 완료
#  -> 진행 중: 12000 / 23523 매치 변환 완료
#  -> 진행 중: 13000 / 23523 매치 변환 완료
#  -> 진행 중: 14000 / 23523 매치 변환 완료
#  -> 진행 중: 15000 / 23523 매치 변환 완료
#  -> 진행 중: 16000 / 23523 매치 변환 완료
#  -> 진행 중: 17000 / 23523 매치 변환 완료
#  -> 진행 중: 18000 / 23523 매치 변환 완료
#  -> 진행 중: 19000 / 23523 매치 변환 완료
#  -> 진행 중: 20000 / 23523 매치 변환 완료
#  -> 진행 중: 21000 / 23523 매치 변환 완료
#  -> 진행 중: 22000 / 23523 매치 변환 완료
#  -> 진행 중: 23000 / 23523 매치 변환 완료
#
# 3. 변환된 데이터를 DataFrame으로 조립하는 중...
#  -> 최종 데이터 크기: 235080행(플레이어 수), 154열
#
# 4. CSV 파일로 저장하는 중입니다...
#  -> 저장 완료! 아래 경로에서 확인해주세요.
# D:\바탕화면\데이터 분석\프로젝트\04 최종 프로젝트\구글 드라이브\details_kr_part1_flattened.csv
#    assists  baronKills  bountyLevel  ch_abilityUses  ch_acesBefore15Minutes  \
# 0        2           0          NaN             110                       0
# 1        3           0          NaN             254                       0
# 2        4           0          NaN             115                       0
# 3        5           0          NaN              60                       0
# 4        4           0          NaN              97                       0
#
#    ch_alliedJungleMonsterKills  ch_baronBuffGoldAdvantageOverThreshold  \
# 0                            0                                     NaN
# 1                           15                                     NaN
# 2                            0                                     NaN
# 3                            0                                     NaN
# 4                            0                                     NaN
#
#    ch_baronTakedowns  ch_bountyGold  ch_buffsStolen  ...  \
# 0                  0       0.000000               0  ...
# 1                  0     469.360535               1  ...
# 2                  0     637.141968               0  ...
# 3                  0     359.220337               0  ...
# 4                  0       0.000000               0  ...
#
#    trueDamageDealtToChampions  trueDamageTaken  turretKills  turretTakedowns  \
# 0                           0               32            1                1
# 1                          84              471            0                0
# 2                           0               59            0                1
# 3                           0              397            0                0
# 4                         299              615            0                0
#
#    turretsLost  visionScore  visionWardsBoughtInGame  wardsKilled  \
# 0            1            7                        0            0
# 1            1            3                        1            1
# 2            1            9                        0            1
# 3            1            9                        0            1
# 4            1           30                        7            3
#
#    wardsPlaced    win
# 0            5  False
# 1            1  False
# 2            5  False
# 3            5  False
# 4           17  False
#
# [5 rows x 154 columns]

# %%
# timeline_kr_part1.parquet csv로 변환
import pandas as pd
import numpy as np
import pyarrow.parquet as pq
import os
import gc

def extract_all_timeline_frames(input_path, output_path):
    """
    타임라인 파일에서 1분 단위의 플레이어의 모든 상태(위치, 골드, 데미지스탯, 챔피언스탯 등)를
    동적으로 추출하여 CSV로 안전하게 저장합니다.
    """
    if not os.path.exists(input_path):
        print(f"오류: 지정한 경로에 파일이 존재하지 않습니다.\n{input_path}")
        return
        
    try:
        print("1. 타임라인 전체 데이터 추출 준비 중...")
        parquet_file = pq.ParquetFile(input_path)
        total_batches = parquet_file.num_row_groups
        print(f" -> 총 {total_batches}개의 데이터 그룹 발견.\n")
        
        if os.path.exists(output_path):
            os.remove(output_path)
            
        is_first_batch = True
        csv_columns = [] # CSV 컬럼 순서를 고정하기 위한 변수
        
        print("2. 1분 단위 플레이어 [전체] 데이터 추출 및 저장 시작...")
        
        # 메모리 안정을 위해 50게임씩 처리
        for batch_idx, batch in enumerate(parquet_file.iter_batches(batch_size=50)):
            df_chunk = batch.to_pandas()
            processed_rows = []
            
            for index, row in df_chunk.iterrows():
                # 데이터 안전 변환
                metadata = row.get('metadata', {})
                info = row.get('info', {})
                
                if pd.notnull(metadata) and not isinstance(metadata, dict):
                    try: metadata = dict(metadata)
                    except: metadata = {}
                if pd.notnull(info) and not isinstance(info, dict):
                    try: info = dict(info)
                    except: info = {}
                    
                match_id = metadata.get('matchId', 'Unknown')
                frames = info.get('frames', [])
                
                if isinstance(frames, np.ndarray):
                    frames = frames.tolist()
                if not isinstance(frames, list):
                    continue
                
                for frame in frames:
                    if not isinstance(frame, dict):
                        continue
                        
                    timestamp = frame.get('timestamp', 0)
                    minute = timestamp // 60000 
                    
                    participant_frames = frame.get('participantFrames', {})
                    if not isinstance(participant_frames, dict):
                        continue
                        
                    for pid, p_data in participant_frames.items():
                        if not isinstance(p_data, dict):
                            continue
                            
                        # 1) 기본 필수 정보 세팅
                        row_dict = {
                            'matchId': match_id,
                            'minute': minute,
                            'participantId': p_data.get('participantId', pid)
                        }
                        
                        # 2) p_data 내의 '모든' 정보를 동적으로 펼치기(Flatten)
                        for key, value in p_data.items():
                            if key == 'participantId': 
                                continue # 위에서 이미 넣었으므로 패스
                                
                            if isinstance(value, dict):
                                # damageStats, championStats, position 등 내부 딕셔너리 분해
                                for sub_key, sub_val in value.items():
                                    row_dict[f"{key}_{sub_key}"] = sub_val
                            else:
                                # 일반 수치형 데이터 (totalGold, level, xp 등)
                                row_dict[key] = value
                                
                        processed_rows.append(row_dict)
                        
            # 조립된 데이터를 CSV에 저장
            if processed_rows:
                chunk_df = pd.DataFrame(processed_rows)
                
                if is_first_batch:
                    # 첫 번째 배치에서 생성된 컬럼 리스트와 순서를 기억합니다.
                    csv_columns = chunk_df.columns.tolist()
                    chunk_df.to_csv(output_path, mode='w', index=False, encoding='utf-8-sig')
                    is_first_batch = False
                else:
                    # 두 번째 배치부터는 반드시 첫 번째 배치와 동일한 컬럼 순서로 정렬합니다.
                    # (만약 특정 판에서 누락된 열이 있다면 자동으로 빈칸(NaN) 처리하여 표가 밀리는 것을 방지)
                    chunk_df = chunk_df.reindex(columns=csv_columns)
                    chunk_df.to_csv(output_path, mode='a', header=False, index=False, encoding='utf-8-sig')
                    
            # 사용이 끝난 메모리 즉시 반환 (OOM 방지)
            del df_chunk
            del processed_rows
            del chunk_df
            gc.collect()
            
            print(f" -> 진행 상황: {batch_idx + 1} / {total_batches} 청크 추출 및 저장 완료")
            
        print(f"\n3. 모든 추출이 성공적으로 완료되었습니다!\n저장 경로: {output_path}")

    except Exception as e:
        print(f"작업 중 오류 발생: {e}")

# ==========================================
# 실행을 위한 설정 영역
# ==========================================

file_path_in = r"D:\바탕화면\데이터 분석\프로젝트\04 최종 프로젝트\구글 드라이브\timeline_kr_part1.parquet"

# 이전 파일과 구분하기 위해 이름 뒤에 '_all_data'를 붙였습니다.
file_path_out = r"D:\바탕화면\데이터 분석\프로젝트\04 최종 프로젝트\구글 드라이브\timeline_kr_part1_all_data.csv"

# 함수 실행
extract_all_timeline_frames(file_path_in, file_path_out)
# Out:
# 1. 타임라인 전체 데이터 추출 준비 중...
#  -> 총 1개의 데이터 그룹 발견.
#
# 2. 1분 단위 플레이어 [전체] 데이터 추출 및 저장 시작...
#  -> 진행 상황: 1 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 2 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 3 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 4 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 5 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 6 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 7 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 8 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 9 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 10 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 11 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 12 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 13 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 14 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 15 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 16 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 17 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 18 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 19 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 20 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 21 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 22 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 23 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 24 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 25 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 26 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 27 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 28 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 29 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 30 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 31 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 32 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 33 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 34 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 35 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 36 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 37 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 38 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 39 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 40 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 41 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 42 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 43 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 44 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 45 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 46 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 47 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 48 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 49 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 50 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 51 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 52 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 53 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 54 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 55 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 56 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 57 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 58 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 59 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 60 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 61 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 62 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 63 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 64 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 65 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 66 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 67 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 68 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 69 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 70 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 71 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 72 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 73 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 74 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 75 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 76 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 77 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 78 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 79 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 80 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 81 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 82 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 83 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 84 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 85 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 86 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 87 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 88 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 89 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 90 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 91 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 92 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 93 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 94 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 95 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 96 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 97 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 98 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 99 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 100 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 101 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 102 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 103 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 104 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 105 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 106 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 107 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 108 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 109 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 110 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 111 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 112 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 113 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 114 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 115 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 116 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 117 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 118 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 119 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 120 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 121 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 122 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 123 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 124 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 125 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 126 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 127 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 128 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 129 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 130 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 131 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 132 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 133 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 134 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 135 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 136 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 137 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 138 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 139 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 140 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 141 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 142 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 143 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 144 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 145 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 146 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 147 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 148 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 149 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 150 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 151 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 152 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 153 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 154 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 155 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 156 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 157 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 158 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 159 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 160 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 161 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 162 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 163 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 164 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 165 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 166 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 167 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 168 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 169 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 170 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 171 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 172 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 173 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 174 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 175 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 176 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 177 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 178 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 179 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 180 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 181 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 182 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 183 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 184 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 185 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 186 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 187 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 188 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 189 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 190 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 191 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 192 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 193 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 194 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 195 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 196 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 197 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 198 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 199 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 200 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 201 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 202 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 203 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 204 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 205 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 206 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 207 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 208 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 209 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 210 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 211 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 212 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 213 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 214 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 215 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 216 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 217 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 218 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 219 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 220 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 221 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 222 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 223 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 224 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 225 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 226 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 227 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 228 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 229 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 230 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 231 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 232 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 233 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 234 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 235 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 236 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 237 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 238 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 239 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 240 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 241 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 242 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 243 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 244 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 245 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 246 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 247 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 248 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 249 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 250 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 251 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 252 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 253 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 254 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 255 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 256 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 257 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 258 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 259 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 260 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 261 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 262 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 263 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 264 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 265 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 266 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 267 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 268 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 269 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 270 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 271 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 272 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 273 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 274 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 275 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 276 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 277 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 278 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 279 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 280 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 281 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 282 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 283 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 284 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 285 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 286 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 287 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 288 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 289 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 290 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 291 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 292 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 293 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 294 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 295 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 296 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 297 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 298 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 299 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 300 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 301 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 302 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 303 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 304 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 305 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 306 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 307 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 308 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 309 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 310 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 311 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 312 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 313 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 314 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 315 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 316 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 317 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 318 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 319 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 320 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 321 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 322 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 323 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 324 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 325 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 326 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 327 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 328 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 329 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 330 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 331 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 332 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 333 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 334 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 335 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 336 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 337 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 338 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 339 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 340 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 341 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 342 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 343 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 344 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 345 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 346 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 347 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 348 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 349 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 350 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 351 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 352 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 353 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 354 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 355 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 356 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 357 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 358 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 359 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 360 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 361 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 362 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 363 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 364 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 365 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 366 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 367 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 368 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 369 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 370 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 371 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 372 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 373 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 374 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 375 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 376 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 377 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 378 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 379 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 380 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 381 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 382 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 383 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 384 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 385 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 386 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 387 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 388 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 389 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 390 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 391 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 392 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 393 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 394 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 395 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 396 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 397 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 398 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 399 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 400 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 401 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 402 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 403 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 404 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 405 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 406 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 407 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 408 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 409 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 410 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 411 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 412 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 413 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 414 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 415 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 416 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 417 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 418 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 419 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 420 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 421 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 422 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 423 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 424 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 425 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 426 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 427 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 428 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 429 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 430 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 431 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 432 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 433 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 434 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 435 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 436 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 437 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 438 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 439 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 440 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 441 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 442 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 443 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 444 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 445 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 446 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 447 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 448 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 449 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 450 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 451 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 452 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 453 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 454 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 455 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 456 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 457 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 458 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 459 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 460 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 461 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 462 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 463 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 464 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 465 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 466 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 467 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 468 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 469 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 470 / 1 청크 추출 및 저장 완료
#  -> 진행 상황: 471 / 1 청크 추출 및 저장 완료
#
# 3. 모든 추출이 성공적으로 완료되었습니다!
# 저장 경로: D:\바탕화면\데이터 분석\프로젝트\04 최종 프로젝트\구글 드라이브\timeline_kr_part1_all_data.csv

# %%
# timeline.csv 파일에서 회의로 통해 나눈 컬럼만 뽑기
import pandas as pd
import os

def filter_timeline_columns_fixed(input_csv, output_csv):
    """
    점(.) 대신 밑줄(_)을 사용하여 damageStats 컬럼을 정확히 필터링합니다.
    """
    if not os.path.exists(input_csv):
        print(f"오류: '{input_csv}' 파일을 찾을 수 없습니다. 경로를 확인해주세요.")
        return

    print("1. 원본 파일의 컬럼(열) 구조를 분석 중입니다...")
    
    # 0행만 읽어서 전체 컬럼명 파악
    actual_columns = pd.read_csv(input_csv, nrows=0).columns.tolist()
    
    # [수정됨] 점(.) 대신 밑줄(_) 사용 및 필수 키워드 추가
    keep_keywords = [
        "matchId",        # 어떤 게임인지 알아야 하므로 추가
        "minute",         # 게임 시간(분) 추가
        "timestamp",
        "events",
        "participantId",
        "totalGold",
        "level",
        "xp",
        "minionsKilled",
        "jungleMinionsKilled",
        "timeEnemySpentControlled",
        "damageStats_magicDamageDone",
        "damageStats_magicDamageDoneToChampions",
        "damageStats_magicDamageTaken",
        "damageStats_physicalDamageDone",
        "damageStats_physicalDamageDoneToChampions",
        "damageStats_physicalDamageTaken",
        "damageStats_totalDamageDone",
        "damageStats_totalDamageDoneToChampions",
        "damageStats_totalDamageTaken",
        "damageStats_trueDamageDone",
        "damageStats_trueDamageDoneToChampions",
        "damageStats_trueDamageTaken"
    ]
    
    columns_to_keep = []
    
    for col in actual_columns:
        if any(keyword in col for keyword in keep_keywords):
            columns_to_keep.append(col)
            
    print(f" -> 총 {len(actual_columns)}개의 컬럼 중 {len(columns_to_keep)}개의 컬럼만 남깁니다.")
    
    # 제대로 잡혔는지 확인하기 위해 데미지 스탯 일부 출력
    damage_cols_found = [c for c in columns_to_keep if 'damageStats' in c]
    print(f" -> [확인용] 찾은 데미지 스탯 개수: {len(damage_cols_found)}개")
    if damage_cols_found:
        print(f" -> 예시: {damage_cols_found[:3]}")
    
    if os.path.exists(output_csv):
        os.remove(output_csv)
        
    print("\n2. 선택된 컬럼만 추출하여 새로운 CSV로 저장합니다... (메모리 안전 모드)")
    
    is_first = True
    for chunk in pd.read_csv(input_csv, usecols=columns_to_keep, chunksize=10000):
        if is_first:
            chunk.to_csv(output_csv, mode='w', index=False, encoding='utf-8-sig')
            is_first = False
        else:
            chunk.to_csv(output_csv, mode='a', header=False, index=False, encoding='utf-8-sig')
            
    print(f"\n3. 깔끔하게 정리가 완료되었습니다! 파일 저장 경로:\n{output_csv}")

# ==========================================
# 실행을 위한 파일 경로 설정
# ==========================================

file_path_in = r"D:\바탕화면\데이터 분석\프로젝트\04 최종 프로젝트\구글 드라이브\timeline_kr_part1_all_data.csv"
file_path_out = r"D:\바탕화면\데이터 분석\프로젝트\04 최종 프로젝트\구글 드라이브\timeline_kr_part1_all_data_filtered.csv"

# 함수 실행
filter_timeline_columns_fixed(file_path_in, file_path_out)
# Out:
# 1. 원본 파일의 컬럼(열) 구조를 분석 중입니다...
#  -> 총 50개의 컬럼 중 21개의 컬럼만 남깁니다.
#  -> [확인용] 찾은 데미지 스탯 개수: 12개
#  -> 예시: ['damageStats_magicDamageDone', 'damageStats_magicDamageDoneToChampions', 'damageStats_magicDamageTaken']
#
# 2. 선택된 컬럼만 추출하여 새로운 CSV로 저장합니다... (메모리 안전 모드)
#
# 3. 깔끔하게 정리가 완료되었습니다! 파일 저장 경로:
# D:\바탕화면\데이터 분석\프로젝트\04 최종 프로젝트\구글 드라이브\timeline_kr_part1_all_data_filtered.csv

# %%
# 데이터 확인용
details_data = pd.read_csv(r"D:\바탕화면\데이터 분석\프로젝트\04 최종 프로젝트\구글 드라이브\details_kr_part1_flattened.csv")

details_data
# Out:
#         assists  baronKills  bountyLevel  ch_abilityUses  \
# 0             2           0          NaN             110
# 1             3           0          NaN             254
# 2             4           0          NaN             115
# 3             5           0          NaN              60
# 4             4           0          NaN              97
# ...         ...         ...          ...             ...
# 235075        9           0          NaN             176
# 235076        4           1          NaN             492
# 235077        8           0          NaN             238
# 235078        1           0          NaN             206
# 235079        8           0          NaN             152
#
#         ch_acesBefore15Minutes  ch_alliedJungleMonsterKills  \
# 0                            0                            0
# 1                            0                           15
# 2                            0                            0
# 3                            0                            0
# 4                            0                            0
# ...                        ...                          ...
# 235075                       0                            0
# 235076                       0                           66
# 235077                       0                            0
# 235078                       0                           40
# 235079                       0                            0
#
#         ch_baronBuffGoldAdvantageOverThreshold  ch_baronTakedowns  \
# 0                                          NaN                  0
# 1                                          NaN                  0
# 2                                          NaN                  0
# 3                                          NaN                  0
# 4                                          NaN                  0
# ...                                        ...                ...
# 235075                                     1.0                  0
# 235076                                     1.0                  1
# 235077                                     1.0                  1
# 235078                                     1.0                  0
# 235079                                     1.0                  1
#
#         ch_bountyGold  ch_buffsStolen  ...  trueDamageDealtToChampions  \
# 0            0.000000               0  ...                           0
# 1          469.360535               1  ...                          84
# 2          637.141968               0  ...                           0
# 3          359.220337               0  ...                           0
# 4            0.000000               0  ...                         299
# ...               ...             ...  ...                         ...
# 235075       0.000000               0  ...                         219
# 235076       0.000000               3  ...                        3983
# 235077       0.000000               0  ...                         670
# 235078       0.000000               2  ...                         604
# 235079       0.000000               0  ...                         947
#
#         trueDamageTaken  turretKills  turretTakedowns  turretsLost  \
# 0                    32            1                1            1
# 1                   471            0                0            1
# 2                    59            0                1            1
# 3                   397            0                0            1
# 4                   615            0                0            1
# ...                 ...          ...              ...          ...
# 235075             1898            0                2            1
# 235076             1106            2                4            1
# 235077              957            2                3            1
# 235078             1222            5                6            1
# 235079              664            0                0            1
#
#         visionScore  visionWardsBoughtInGame  wardsKilled  wardsPlaced    win
# 0                 7                        0            0            5  False
# 1                 3                        1            1            1  False
# 2                 9                        0            1            5  False
# 3                 9                        0            1            5  False
# 4                30                        7            3           17  False
# ...             ...                      ...          ...          ...    ...
# 235075           24                        6            2            6   True
# 235076           29                        1            2            5   True
# 235077           29                        4            3           13   True
# 235078           19                        1            1           13   True
# 235079           88                        6            9           34   True
#
# [235080 rows x 154 columns]

# %%
#매치와타임 null값 확인
import pandas as pd

def check_null_values(file_path):
    """
    CSV 파일 내의 Null(결측치) 값을 검사하고,
    어떤 열에 몇 개의 Null이 있는지 위치와 비율을 출력합니다.
    """
    import os
    if not os.path.exists(file_path):
        print(f"오류: 파일을 찾을 수 없습니다.\n경로: {file_path}\n")
        return

    print(f"{"="*50}")
    print(f"🔍 파일 검사 시작: {os.path.basename(file_path)}")
    print(f"{"="*50}")
    
    try:
        # 데이터 불러오기 (메모리 절약을 위해 low_memory=False 설정)
        df = pd.read_csv(file_path, low_memory=False)
        
        # 1. 전체 데이터 크기
        total_rows = len(df)
        print(f"▶ 총 데이터 크기: {total_rows}행, {len(df.columns)}열")
        
        # 2. 결측치(Null)가 있는 열만 필터링
        null_counts = df.isnull().sum()
        null_cols = null_counts[null_counts > 0]
        
        if len(null_cols) == 0:
            print("\n✅ 이 파일에는 Null(결측치) 값이 전혀 없습니다!")
        else:
            print(f"\n⚠️ Null 값이 존재하는 열(Column)은 총 {len(null_cols)}개입니다.")
            print("▼ Null 개수 및 비율 (가장 많은 열부터 최대 20개 출력):")
            
            # 보기 편하도록 데이터프레임으로 만들어 출력
            null_df = pd.DataFrame({
                'Null 개수': null_cols,
                'Null 비율(%)': (null_cols / total_rows * 100).round(2)
            }).sort_values(by='Null 개수', ascending=False)
            
            # 주피터 환경에서 표 형태로 출력
            display(null_df.head(20))
            
        # 3. 태블로 조인(Join) 핵심 키 검사
        print("\n[태블로 연결 키 특별 검사]")
        key_cols = ['matchId', 'participantId']
        for col in key_cols:
            if col in df.columns:
                null_key_count = df[col].isnull().sum()
                if null_key_count > 0:
                    print(f" 🚨 치명적 오류: 조인 키 '{col}'에 Null 값이 {null_key_count}개 존재합니다! (반드시 수정 필요)")
                else:
                    print(f" 🟢 정상: 조인 키 '{col}'에는 Null 값이 없습니다.")
            else:
                print(f" ⚪ 주의: '{col}' 열이 파일에 아예 존재하지 않습니다.")
        print("\n")
        
    except Exception as e:
        print(f"오류 발생: {e}\n")

# ==========================================
# 실행을 위한 파일 경로 설정
# ==========================================

details_file = r"D:\바탕화면\데이터 분석\프로젝트\04 최종 프로젝트\구글 드라이브\details_kr_part1_flattened.csv"
timeline_file = r"D:\바탕화면\데이터 분석\프로젝트\04 최종 프로젝트\구글 드라이브\timeline_kr_part1_all_filtered.csv"

# 두 파일 각각 검사 실행
check_null_values(details_file)
check_null_values(timeline_file)
# Out:
# ==================================================
# 🔍 파일 검사 시작: details_kr_part1_flattened.csv
# ==================================================
# ▶ 총 데이터 크기: 235080행, 154열
#
# ⚠️ Null 값이 존재하는 열(Column)은 총 20개입니다.
# ▼ Null 개수 및 비율 (가장 많은 열부터 최대 20개 출력):
#                                               Null 개수  Null 비율(%)
# ch_hadAfkTeammate                              230879       98.21
# ch_highestCrowdControlScore                    211636       90.03
# ch_highestChampionDamage                       211594       90.01
# ch_highestWardKills                            206840       87.99
# ch_junglerKillsEarlyJungle                     188067       80.00
# ch_killsOnLanersEarlyJungleAsJungler           188067       80.00
# ch_baronBuffGoldAdvantageOverThreshold         185895       79.08
# damageDealtToEpicMonsters                      158280       67.33
# bountyLevel                                    137950       58.68
# ch_controlWardTimeCoverageInRiverOrEnemyHalf   110312       46.93
# ch_killsOnOtherLanesEarlyJungleAsLaner          47026       20.00
# ch_playedChampSelectPosition                     9493        4.04
# ch_laningPhaseGoldExpAdvantage                   7096        3.02
# ch_earlyLaningPhaseGoldExpAdvantage              6106        2.60
# ch_maxLevelLeadLaneOpponent                      5806        2.47
# ch_maxCsAdvantageOnLaneOpponent                  5806        2.47
# ch_visionScoreAdvantageLaneOpponent              5806        2.47
# ch_killParticipation                             3890        1.65
# ch_teamDamagePercentage                           305        0.13
# teamPosition                                      135        0.06
# [태블로 연결 키 특별 검사]
#  🟢 정상: 조인 키 'matchId'에는 Null 값이 없습니다.
#  🟢 정상: 조인 키 'participantId'에는 Null 값이 없습니다.
#
#
# 오류: 파일을 찾을 수 없습니다.
# 경로: D:\바탕화면\데이터 분석\프로젝트\04 최종 프로젝트\구글 드라이브\timeline_kr_part1_all_filtered.csv

# %%
#matchid null 확인
import pandas as pd
import os

def check_matchid_nulls(file_path):
    """
    지정된 파일에서 'matchId' 컬럼에 Null 값이 있는지 집중 검사합니다.
    """
    if not os.path.exists(file_path):
        print(f"오류: 지정한 경로에 파일이 없습니다.\n경로: {file_path}\n")
        return

    print(f"{'='*50}")
    print(f"🔍 [matchId] Null 집중 검사: {os.path.basename(file_path)}")
    print(f"{'='*50}")
    
    try:
        # 파일 불러오기
        df = pd.read_csv(file_path, low_memory=False)
        total_rows = len(df)
        
        # matchId 컬럼 존재 여부 확인
        if 'matchId' not in df.columns:
            print("❌ 오류: 이 파일에는 'matchId' 컬럼이 존재하지 않습니다!")
            return
            
        # matchId가 Null인 행 필터링
        null_mask = df['matchId'].isnull()
        result_df = df[null_mask]
        
        null_count = len(result_df)
        
        print(f"▶ 전체 데이터: {total_rows}행")
        
        if null_count > 0:
            print(f"🚨 경고: 'matchId'가 없는(Null) 행이 {null_count}개 발견되었습니다!")
            print("\n[문제의 데이터 미리보기 (상위 5개)]")
            
            # matchId를 맨 앞으로 가져와서 출력
            cols = ['matchId'] + [c for c in df.columns if c != 'matchId']
            display(result_df[cols].head(5))
        else:
            print("✅ 완벽합니다! 'matchId' 컬럼에 Null 값이 단 하나도 없습니다. (조인 안전)")
            
    except Exception as e:
        print(f"검사 중 오류 발생: {e}")
    print("\n")

# ==========================================
# 실행 영역: 두 파일 모두 검사
# ==========================================

details_file = r"D:\바탕화면\데이터 분석\프로젝트\04 최종 프로젝트\구글 드라이브\details_kr_part1_flattened.csv"
timeline_file = r"D:\바탕화면\데이터 분석\프로젝트\04 최종 프로젝트\구글 드라이브\timeline_kr_part1_all_data_filtered.csv"

# 1. Details 파일 검사
check_matchid_nulls(details_file)

# 2. Timeline 파일 검사
check_matchid_nulls(timeline_file)
# Out:
# ==================================================
# 🔍 [matchId] Null 집중 검사: details_kr_part1_flattened.csv
# ==================================================
# ▶ 전체 데이터: 235080행
# ✅ 완벽합니다! 'matchId' 컬럼에 Null 값이 단 하나도 없습니다. (조인 안전)
#
#
# ==================================================
# 🔍 [matchId] Null 집중 검사: timeline_kr_part1_all_data_filtered.csv
# ==================================================
# ▶ 전체 데이터: 6967570행
# ✅ 완벽합니다! 'matchId' 컬럼에 Null 값이 단 하나도 없습니다. (조인 안전)

# %%
# details.parquet 파일들 csv 파일 전환
import pandas as pd
import os
import glob

def batch_convert_details_exclude_kr(target_folder):
    """
    폴더 내에서 이름이 'details'로 시작하는 Parquet 파일을 찾고, 
    그 중 'kr'이 포함된 파일을 제외한 나머지를 CSV로 일괄 변환합니다.
    """
    if not os.path.exists(target_folder):
        print(f"오류: 지정한 폴더 경로가 존재하지 않습니다.\n{target_folder}")
        return
        
    # 1. 'details'로 시작하는 .parquet 파일만 1차 검색
    search_pattern = os.path.join(target_folder, "details*.parquet")
    all_files = glob.glob(search_pattern)
    
    if len(all_files) == 0:
        print(f"알림: 해당 폴더에 'details'로 시작하는 Parquet 파일이 없습니다.\n{target_folder}")
        return
        
    print(f"'details'로 시작하는 Parquet 파일을 총 {len(all_files)}개 찾았습니다.")
    
    # 2. 파일명에 'kr'이 포함된 파일 2차 제외
    target_files = [f for f in all_files if 'kr' not in os.path.basename(f).lower()]
    
    print(f"그 중 'kr'이 포함된 파일을 제외하고, 총 {len(target_files)}개의 파일만 변환을 시작합니다.\n")
    print("-" * 50)
    
    if len(target_files) == 0:
        print("변환할 대상 파일이 없습니다.")
        return

    # 3. 필터링된 파일 목록만 순회하며 변환
    for input_path in target_files:
        file_name = os.path.basename(input_path)
        output_path = os.path.splitext(input_path)[0] + ".csv"
        
        try:
            print(f"변환 진행 중: {file_name} ...", end=" ")
            
            # 데이터 불러오기
            df = pd.read_parquet(input_path, engine='pyarrow')
            
            # CSV로 저장 (한글 깨짐 방지 적용)
            df.to_csv(output_path, index=False, encoding='utf-8-sig')
            
            print("성공!")
            
        except Exception as e:
            print(f"실패! (사유: {e})")
            
    print("-" * 50)
    print("선택된 파일들의 변환 작업이 모두 완료되었습니다!")

# ==========================================
# 실행을 위한 폴더 경로 설정
# ==========================================
folder_path = r"D:\바탕화면\데이터 분석\프로젝트\04 최종 프로젝트\구글 드라이브"

# 함수 실행
batch_convert_details_exclude_kr(folder_path)
# Out:
# 'details'로 시작하는 Parquet 파일을 총 15개 찾았습니다.
# 그 중 'kr'이 포함된 파일을 제외하고, 총 14개의 파일만 변환을 시작합니다.
#
# --------------------------------------------------
# 변환 진행 중: details_br1_part1.parquet ... 성공!
# 변환 진행 중: details_eun1_part1.parquet ... 성공!
# 변환 진행 중: details_euw1_part1.parquet ... 성공!
# 변환 진행 중: details_euw1_part2.parquet ... 성공!
# 변환 진행 중: details_jp1_part1.parquet ... 성공!
# 변환 진행 중: details_la1_part1.parquet ... 성공!
# 변환 진행 중: details_la2_part1.parquet ... 성공!
# 변환 진행 중: details_me1_part1.parquet ... 성공!
# 변환 진행 중: details_na1_part1.parquet ... 성공!
# 변환 진행 중: details_oc1_part1.parquet ... 성공!
# 변환 진행 중: details_ru_part1.parquet ... 성공!
# 변환 진행 중: details_tr1_part1.parquet ... 성공!
# 변환 진행 중: details_tw2_part1.parquet ... 성공!
# 변환 진행 중: details_vn2_part1.parquet ... 성공!
# --------------------------------------------------
# 선택된 파일들의 변환 작업이 모두 완료되었습니다!

# %%
# details.csv들 회의컬럼만 뽑기
import pandas as pd
import numpy as np
import os
import glob
import gc

def parse_string_data(val):
    """ 
    CSV에 단순 문자열로 저장되어 버린 딕셔너리/배열 데이터를 
    다시 파이썬이 이해할 수 있는 객체로 복원하는 핵심 함수입니다.
    """
    if pd.isna(val):
        return {}
    if isinstance(val, (dict, list)):
        return val
    if isinstance(val, str):
        try:
            # 문자열 안에 적힌 array 등을 실제 numpy 기능으로 인식하도록 맵핑하여 복원합니다.
            return eval(val, {"array": np.array, "nan": np.nan, "object": object})
        except:
            return {}
    return {}

def batch_process_csv_to_flattened_exclude_kr(target_folder, target_cols):
    """
    미리 1차 변환된 'details*.csv' 파일들을 찾아 데이터를 복원하고,
    'kr'을 제외한 파일들을 평탄화(Flatten)하여 새로 저장합니다.
    """
    if not os.path.exists(target_folder):
        print(f"오류: 지정한 폴더 경로가 존재하지 않습니다.\n{target_folder}")
        return
        
    # 1. 'details'로 시작하는 .csv 파일 검색
    search_pattern = os.path.join(target_folder, "details*.csv")
    all_files = glob.glob(search_pattern)
    
    # 2. 'kr'이 포함된 파일과 이미 평탄화된('_flattened') 파일 제외
    target_files = []
    for f in all_files:
        fname = os.path.basename(f).lower()
        if 'kr' not in fname and '_flattened' not in fname:
            target_files.append(f)
            
    print(f"'kr' 및 기변환 파일을 제외하고, 총 {len(target_files)}개의 CSV 파일 평탄화를 시작합니다.\n")
    print("=" * 60)
    
    if len(target_files) == 0:
        print("변환할 대상 파일이 없습니다.")
        return

    # 3. 대상 파일들을 순회하며 변환 시작
    for input_path in target_files:
        file_name = os.path.basename(input_path)
        output_path = os.path.splitext(input_path)[0] + "_flattened.csv"
        
        try:
            print(f"▶ 작업 시작: {file_name}")
            # low_memory=False: 대용량 텍스트 데이터를 안전하게 읽기 위함
            df_raw = pd.read_csv(input_path, low_memory=False)
            total_matches = len(df_raw)
            print(f"  - 총 {total_matches} 매치 로드 완료. 문자열 복원 및 추출 중...")
            
            processed_rows = []
            
            # 4. 개별 매치 데이터 평탄화 로직
            for index, row in df_raw.iterrows():
                
                # CSV에서 문자열로 변한 데이터를 다시 딕셔너리로 복원합니다.
                metadata = parse_string_data(row.get('metadata', "{}"))
                info = parse_string_data(row.get('info', "{}"))

                common_info = {
                    'dataVersion': metadata.get('dataVersion', row.get('dataVersion')),
                    'matchId': metadata.get('matchId', row.get('matchId')),
                    'endOfGameResult': info.get('endOfGameResult', row.get('endOfGameResult')),
                    'gameCreation': info.get('gameCreation', row.get('gameCreation')),
                    'gameDuration': info.get('gameDuration', row.get('gameDuration')),
                    'gameVersion': info.get('gameVersion', row.get('gameVersion')),
                    'queueId': info.get('queueId', row.get('queueId'))
                }
                
                participants = info.get('participants', [])
                
                if isinstance(participants, np.ndarray):
                    participants = participants.tolist()
                    
                if not isinstance(participants, list):
                    continue
                    
                for p in participants:
                    if not isinstance(p, dict):
                        try: p = dict(p)
                        except: continue
                        
                    player_row = {}
                    challenges = p.get('challenges', {})
                    if not isinstance(challenges, dict):
                        try: challenges = dict(challenges)
                        except: challenges = {}
                    
                    for col in target_cols:
                        if col in common_info:
                            player_row[col] = common_info[col]
                        elif col.startswith('ch_'):
                            actual_key = col[3:]  # 'ch_' 제외한 원래 이름
                            player_row[col] = challenges.get(actual_key, None)
                        else:
                            player_row[col] = p.get(col, None)
                            
                    processed_rows.append(player_row)
                    
            # 5. DataFrame 조립 및 CSV 저장
            final_df = pd.DataFrame(processed_rows, columns=target_cols)
            
            if final_df.shape[0] == 0:
                print(f"  - [경고] {file_name}에서 추출된 데이터가 없습니다.")
            else:
                final_df.to_csv(output_path, index=False, encoding='utf-8-sig')
                print(f"  - 성공! (크기: {final_df.shape[0]}행, {final_df.shape[1]}열) -> 저장 완료")
            
            # 메모리 정리 (연속 작업 시 메모리 터짐 방지)
            del df_raw
            del processed_rows
            del final_df
            gc.collect()
            
        except Exception as e:
            print(f"  - 실패! (사유: {e})")
            
    print("=" * 60)
    print("선택된 CSV 파일들의 평탄화 작업이 완료되었습니다!")


# ==========================================
# 실행을 위한 설정 영역
# ==========================================

# 1. 타겟 컬럼 리스트
target_columns = [
    "assists", "baronKills", "bountyLevel", "ch_abilityUses", "ch_acesBefore15Minutes",
    "ch_alliedJungleMonsterKills", "ch_baronBuffGoldAdvantageOverThreshold", "ch_baronTakedowns",
    "ch_bountyGold", "ch_buffsStolen", "ch_completeSupportQuestInTime", "ch_controlWardTimeCoverageInRiverOrEnemyHalf",
    "ch_controlWardsPlaced", "ch_damagePerMinute", "ch_damageTakenOnTeamPercentage", "ch_deathsByEnemyChamps",
    "ch_dragonTakedowns", "ch_earlyLaningPhaseGoldExpAdvantage", "ch_effectiveHealAndShielding", "ch_enemyChampionImmobilizations",
    "ch_enemyJungleMonsterKills", "ch_epicMonsterKillsWithin30SecondsOfSpawn", "ch_epicMonsterSteals", "ch_goldPerMinute",
    "ch_hadAfkTeammate", "ch_highestChampionDamage", "ch_highestCrowdControlScore", "ch_highestWardKills",
    "ch_immobilizeAndKillWithAlly", "ch_initialBuffCount", "ch_initialCrabCount", "ch_jungleCsBefore10Minutes",
    "ch_junglerKillsEarlyJungle", "ch_junglerTakedownsNearDamagedEpicMonster", "ch_kTurretsDestroyedBeforePlatesFall",
    "ch_kda", "ch_killParticipation", "ch_killingSprees", "ch_killsNearEnemyTurret", "ch_killsOnLanersEarlyJungleAsJungler",
    "ch_killsOnOtherLanesEarlyJungleAsLaner", "ch_killsUnderOwnTurret", "ch_knockEnemyIntoTeamAndKill", "ch_landSkillShotsEarlyGame",
    "ch_laneMinionsFirst10Minutes", "ch_laningPhaseGoldExpAdvantage", "ch_legendaryCount", "ch_maxCsAdvantageOnLaneOpponent",
    "ch_maxKillDeficit", "ch_maxLevelLeadLaneOpponent", "ch_mejaisFullStackInTime", "ch_moreEnemyJungleThanOpponent",
    "ch_multikills", "ch_outerTurretExecutesBefore10Minutes", "ch_playedChampSelectPosition", "ch_quickFirstTurret",
    "ch_quickSoloKills", "ch_riftHeraldTakedowns", "ch_saveAllyFromDeath", "ch_scuttleCrabKills", "ch_soloKills",
    "ch_stealthWardsPlaced", "ch_takedowns", "ch_takedownsAfterGainingLevelAdvantage", "ch_takedownsBeforeJungleMinionSpawn",
    "ch_takedownsFirstXMinutes", "ch_takedownsInEnemyFountain", "ch_teamBaronKills", "ch_teamDamagePercentage",
    "ch_teamElderDragonKills", "ch_teamRiftHeraldKills", "ch_turretPlatesTaken", "ch_turretTakedowns", "ch_turretsTakenWithRiftHerald",
    "ch_unseenRecalls", "ch_visionScoreAdvantageLaneOpponent", "ch_visionScorePerMinute", "ch_wardTakedowns",
    "ch_wardTakedownsBefore20M", "champExperience", "champLevel", "championName", "championTransform",
    "damageDealtToBuildings", "damageDealtToEpicMonsters", "damageDealtToObjectives", "damageDealtToTurrets",
    "damageSelfMitigated", "dataVersion", "deaths", "detectorWardsPlaced", "doubleKills", "eligibleForProgression",
    "endOfGameResult", "firstBloodAssist", "firstBloodKill", "firstTowerAssist", "firstTowerKill", "gameCreation",
    "gameDuration", "gameEndedInEarlySurrender", "gameEndedInSurrender", "gameVersion", "goldEarned", "goldSpent",
    "individualPosition", "inhibitorTakedowns", "inhibitorsLost", "itemsPurchased", "killingSprees", "kills",
    "magicDamageDealt", "magicDamageDealtToChampions", "magicDamageTaken", "matchId", "neutralMinionsKilled",
    "objectivesStolen", "objectivesStolenAssists", "participantId", "perks", "physicalDamageDealt", "physicalDamageDealtToChampions",
    "physicalDamageTaken", "queueId", "summonerId", "summonerLevel", "teamEarlySurrendered", "teamId", "teamPosition",
    "timeCCingOthers", "timePlayed", "totalAllyJungleMinionsKilled", "totalDamageDealt", "totalDamageDealtToChampions",
    "totalDamageShieldedOnTeammates", "totalDamageTaken", "totalEnemyJungleMinionsKilled", "totalHeal", "totalHealsOnTeammates",
    "totalMinionsKilled", "totalTimeCCDealt", "totalTimeSpentDead", "totalUnitsHealed", "trueDamageDealt",
    "trueDamageDealtToChampions", "trueDamageTaken", "turretKills", "turretTakedowns", "turretsLost", "visionScore",
    "visionWardsBoughtInGame", "wardsKilled", "wardsPlaced", "win"
]

# 2. 파일들이 있는 폴더 지정
folder_path = r"D:\바탕화면\데이터 분석\프로젝트\04 최종 프로젝트\구글 드라이브"

# 함수 실행!
batch_process_csv_to_flattened_exclude_kr(folder_path, target_columns)
# Out:
# 'kr' 및 기변환 파일을 제외하고, 총 14개의 CSV 파일 평탄화를 시작합니다.
#
# ============================================================
# ▶ 작업 시작: details_br1_part1.csv
#   - 총 9529 매치 로드 완료. 문자열 복원 및 추출 중...
#   - 성공! (크기: 83740행, 154열) -> 저장 완료
# ▶ 작업 시작: details_eun1_part1.csv
#   - 총 11154 매치 로드 완료. 문자열 복원 및 추출 중...
#   - 성공! (크기: 101110행, 154열) -> 저장 완료
# ▶ 작업 시작: details_euw1_part1.csv
#   - 총 13094 매치 로드 완료. 문자열 복원 및 추출 중...
#   - 성공! (크기: 119910행, 154열) -> 저장 완료
# ▶ 작업 시작: details_euw1_part2.csv
#   - 총 13094 매치 로드 완료. 문자열 복원 및 추출 중...
#   - 성공! (크기: 119880행, 154열) -> 저장 완료
# ▶ 작업 시작: details_jp1_part1.csv
#   - 총 1785 매치 로드 완료. 문자열 복원 및 추출 중...
#   - 성공! (크기: 15990행, 154열) -> 저장 완료
# ▶ 작업 시작: details_la1_part1.csv
#   - 총 6518 매치 로드 완료. 문자열 복원 및 추출 중...
#   - 성공! (크기: 58040행, 154열) -> 저장 완료
# ▶ 작업 시작: details_la2_part1.csv
#   - 총 6123 매치 로드 완료. 문자열 복원 및 추출 중...
#   - 성공! (크기: 55220행, 154열) -> 저장 완료
# ▶ 작업 시작: details_me1_part1.csv
#   - 총 309 매치 로드 완료. 문자열 복원 및 추출 중...
#   - 성공! (크기: 2730행, 154열) -> 저장 완료
# ▶ 작업 시작: details_na1_part1.csv
#   - 총 10114 매치 로드 완료. 문자열 복원 및 추출 중...
#   - 성공! (크기: 92000행, 154열) -> 저장 완료
# ▶ 작업 시작: details_oc1_part1.csv
#   - 총 1180 매치 로드 완료. 문자열 복원 및 추출 중...
#   - 성공! (크기: 10910행, 154열) -> 저장 완료
# ▶ 작업 시작: details_ru_part1.csv
#   - 총 1127 매치 로드 완료. 문자열 복원 및 추출 중...
#   - 성공! (크기: 10070행, 154열) -> 저장 완료
# ▶ 작업 시작: details_tr1_part1.csv
#   - 총 5681 매치 로드 완료. 문자열 복원 및 추출 중...
#   - 성공! (크기: 51140행, 154열) -> 저장 완료
# ▶ 작업 시작: details_tw2_part1.csv
#   - 총 1515 매치 로드 완료. 문자열 복원 및 추출 중...
#   - 성공! (크기: 13530행, 154열) -> 저장 완료
# ▶ 작업 시작: details_vn2_part1.csv
#   - 총 7729 매치 로드 완료. 문자열 복원 및 추출 중...
#   - 성공! (크기: 70470행, 154열) -> 저장 완료
# ============================================================
# 선택된 CSV 파일들의 평탄화 작업이 완료되었습니다!

# %%
# timeline.parquet 파일들 csv 파일 전환
import pandas as pd
import pyarrow.parquet as pq
import os
import glob
import gc

def safe_convert_timeline_exclude_kr(target_folder):
    """
    메모리 에러를 방지하기 위해 대용량 Timeline Parquet 파일을 
    아주 작은 조각(Batch)으로 나누어 읽고 CSV로 바로 이어붙여 저장합니다.
    """
    if not os.path.exists(target_folder):
        print(f"오류: 폴더 경로를 확인해주세요.\n{target_folder}")
        return
        
    # 1. 'timeline'으로 시작하는 .parquet 파일 찾기
    search_pattern = os.path.join(target_folder, "timeline*.parquet")
    all_files = glob.glob(search_pattern)
    
    # 2. 'kr'이 포함된 파일 제외
    target_files = [f for f in all_files if 'kr' not in os.path.basename(f).lower()]
    
    print(f"총 {len(target_files)}개의 타임라인 파일 변환을 시작합니다. (kr 제외)\n")
    print("=" * 60)
    
    if len(target_files) == 0:
        print("변환할 타임라인 파일이 없습니다.")
        return

    for input_path in target_files:
        file_name = os.path.basename(input_path)
        output_path = os.path.splitext(input_path)[0] + ".csv"
        
        try:
            print(f"▶ 타임라인 파일 변환 중: {file_name}")
            
            # 파일을 한 번에 메모리에 올리지 않고 객체만 엽니다.
            parquet_file = pq.ParquetFile(input_path)
            
            # 기존에 쓰다 만 파일이 있다면 삭제 (덮어쓰기 오류 방지)
            if os.path.exists(output_path):
                os.remove(output_path)
                
            is_first = True
            batch_count = 0
            
            # 3. 데이터를 아주 작게(한 번에 5개 매치씩) 잘라서 읽습니다.
            # 이 크기를 줄일수록 속도는 조금 느려지지만 메모리가 절대 터지지 않습니다.
            for batch in parquet_file.iter_batches(batch_size=5):
                batch_count += 1
                
                # 조각 데이터를 DataFrame으로 변환
                df_chunk = batch.to_pandas()
                
                # CSV 파일에 이어붙여 저장
                if is_first:
                    # 첫 번째 조각: 컬럼명(Header) 포함하여 파일 생성
                    df_chunk.to_csv(output_path, mode='w', index=False, encoding='utf-8-sig')
                    is_first = False
                else:
                    # 두 번째 조각부터: 컬럼명 없이 밑에 데이터만 추가
                    df_chunk.to_csv(output_path, mode='a', header=False, index=False, encoding='utf-8-sig')
                    
                # 사용한 메모리를 즉시 비워줍니다 (매우 중요!)
                del df_chunk
                gc.collect()
                
                # 현재 진행 상황 표시 (10번째 조각마다 출력)
                if batch_count % 10 == 0:
                    print(f"  ... {batch_count * 5}개 매치 변환 완료 ...")
                    
            print(f"  - 성공! -> {os.path.basename(output_path)} 저장 완료")
            
        except Exception as e:
            print(f"  - 실패! (사유: {e})")
            
    print("=" * 60)
    print("모든 타임라인 변환 작업이 완료되었습니다!")

# ==========================================
# 실행을 위한 설정 영역
# ==========================================

# 파일들이 있는 최상위 폴더 지정
folder_path = r"D:\바탕화면\데이터 분석\프로젝트\04 최종 프로젝트\구글 드라이브"

# 함수 실행!
safe_convert_timeline_exclude_kr(folder_path)
# Out:
# 총 6개의 타임라인 파일 변환을 시작합니다. (kr 제외)
#
# ============================================================
# ▶ 타임라인 파일 변환 중: timeline_oc1_part1.parquet
#   ... 50개 매치 변환 완료 ...
#   ... 100개 매치 변환 완료 ...
#   ... 150개 매치 변환 완료 ...
#   ... 200개 매치 변환 완료 ...
#   ... 250개 매치 변환 완료 ...
#   ... 300개 매치 변환 완료 ...
#   ... 350개 매치 변환 완료 ...
#   ... 400개 매치 변환 완료 ...
#   ... 450개 매치 변환 완료 ...
#   ... 500개 매치 변환 완료 ...
#   ... 550개 매치 변환 완료 ...
#   ... 600개 매치 변환 완료 ...
#   ... 650개 매치 변환 완료 ...
#   ... 700개 매치 변환 완료 ...
#   ... 750개 매치 변환 완료 ...
#   ... 800개 매치 변환 완료 ...
#   ... 850개 매치 변환 완료 ...
#   ... 900개 매치 변환 완료 ...
#   ... 950개 매치 변환 완료 ...
#   ... 1000개 매치 변환 완료 ...
#   ... 1050개 매치 변환 완료 ...
#   ... 1100개 매치 변환 완료 ...
#   ... 1150개 매치 변환 완료 ...
#   - 성공! -> timeline_oc1_part1.csv 저장 완료
# ▶ 타임라인 파일 변환 중: timeline_ru_part1.parquet
#   ... 50개 매치 변환 완료 ...
#   ... 100개 매치 변환 완료 ...
#   ... 150개 매치 변환 완료 ...
#   ... 200개 매치 변환 완료 ...
#   ... 250개 매치 변환 완료 ...
#   ... 300개 매치 변환 완료 ...
#   ... 350개 매치 변환 완료 ...
#   ... 400개 매치 변환 완료 ...
#   ... 450개 매치 변환 완료 ...
#   ... 500개 매치 변환 완료 ...
#   ... 550개 매치 변환 완료 ...
#   ... 600개 매치 변환 완료 ...
#   ... 650개 매치 변환 완료 ...
#   ... 700개 매치 변환 완료 ...
#   ... 750개 매치 변환 완료 ...
#   ... 800개 매치 변환 완료 ...
#   ... 850개 매치 변환 완료 ...
#   ... 900개 매치 변환 완료 ...
#   ... 950개 매치 변환 완료 ...
#   ... 1000개 매치 변환 완료 ...
#   ... 1050개 매치 변환 완료 ...
#   ... 1100개 매치 변환 완료 ...
#   - 성공! -> timeline_ru_part1.csv 저장 완료
# ▶ 타임라인 파일 변환 중: timeline_sg2_part1.parquet
#   ... 50개 매치 변환 완료 ...
#   ... 100개 매치 변환 완료 ...
#   ... 150개 매치 변환 완료 ...
#   ... 200개 매치 변환 완료 ...
#   ... 250개 매치 변환 완료 ...
#   ... 300개 매치 변환 완료 ...
#   ... 350개 매치 변환 완료 ...
#   ... 400개 매치 변환 완료 ...
#   ... 450개 매치 변환 완료 ...
#   ... 500개 매치 변환 완료 ...
#   ... 550개 매치 변환 완료 ...
#   ... 600개 매치 변환 완료 ...
#   ... 650개 매치 변환 완료 ...
#   ... 700개 매치 변환 완료 ...
#   ... 750개 매치 변환 완료 ...
#   ... 800개 매치 변환 완료 ...
#   ... 850개 매치 변환 완료 ...
#   ... 900개 매치 변환 완료 ...
#   ... 950개 매치 변환 완료 ...
#   ... 1000개 매치 변환 완료 ...
#   ... 1050개 매치 변환 완료 ...
#   ... 1100개 매치 변환 완료 ...
#   ... 1150개 매치 변환 완료 ...
#   ... 1200개 매치 변환 완료 ...
#   ... 1250개 매치 변환 완료 ...
#   ... 1300개 매치 변환 완료 ...
#   ... 1350개 매치 변환 완료 ...
#   ... 1400개 매치 변환 완료 ...
#   ... 1450개 매치 변환 완료 ...
#   ... 1500개 매치 변환 완료 ...
#   - 성공! -> timeline_sg2_part1.csv 저장 완료
# ▶ 타임라인 파일 변환 중: timeline_tr1_part1.parquet
#   ... 50개 매치 변환 완료 ...
#   ... 100개 매치 변환 완료 ...
#   ... 150개 매치 변환 완료 ...
#   ... 200개 매치 변환 완료 ...
#   ... 250개 매치 변환 완료 ...
#   ... 300개 매치 변환 완료 ...
#   ... 350개 매치 변환 완료 ...
#   ... 400개 매치 변환 완료 ...
#   ... 450개 매치 변환 완료 ...
#   ... 500개 매치 변환 완료 ...
#   ... 550개 매치 변환 완료 ...
#   ... 600개 매치 변환 완료 ...
#   ... 650개 매치 변환 완료 ...
#   ... 700개 매치 변환 완료 ...
#   ... 750개 매치 변환 완료 ...
#   ... 800개 매치 변환 완료 ...
#   ... 850개 매치 변환 완료 ...
#   ... 900개 매치 변환 완료 ...
#   ... 950개 매치 변환 완료 ...
#   ... 1000개 매치 변환 완료 ...
#   ... 1050개 매치 변환 완료 ...
#   ... 1100개 매치 변환 완료 ...
#   ... 1150개 매치 변환 완료 ...
#   ... 1200개 매치 변환 완료 ...
#   ... 1250개 매치 변환 완료 ...
#   ... 1300개 매치 변환 완료 ...
#   ... 1350개 매치 변환 완료 ...
#   ... 1400개 매치 변환 완료 ...
#   ... 1450개 매치 변환 완료 ...
#   ... 1500개 매치 변환 완료 ...
#   ... 1550개 매치 변환 완료 ...
#   ... 1600개 매치 변환 완료 ...
#   ... 1650개 매치 변환 완료 ...
#   ... 1700개 매치 변환 완료 ...
#   ... 1750개 매치 변환 완료 ...
#   ... 1800개 매치 변환 완료 ...
#   ... 1850개 매치 변환 완료 ...
#   ... 1900개 매치 변환 완료 ...
#   ... 1950개 매치 변환 완료 ...
#   ... 2000개 매치 변환 완료 ...
#   ... 2050개 매치 변환 완료 ...
#   ... 2100개 매치 변환 완료 ...
#   ... 2150개 매치 변환 완료 ...
#   ... 2200개 매치 변환 완료 ...
#   ... 2250개 매치 변환 완료 ...
#   ... 2300개 매치 변환 완료 ...
#   ... 2350개 매치 변환 완료 ...
#   ... 2400개 매치 변환 완료 ...
#   ... 2450개 매치 변환 완료 ...
#   ... 2500개 매치 변환 완료 ...
#   ... 2550개 매치 변환 완료 ...
#   ... 2600개 매치 변환 완료 ...
#   ... 2650개 매치 변환 완료 ...
#   ... 2700개 매치 변환 완료 ...
#   ... 2750개 매치 변환 완료 ...
#   ... 2800개 매치 변환 완료 ...
#   ... 2850개 매치 변환 완료 ...
#   ... 2900개 매치 변환 완료 ...
#   ... 2950개 매치 변환 완료 ...
#   ... 3000개 매치 변환 완료 ...
#   ... 3050개 매치 변환 완료 ...
#   ... 3100개 매치 변환 완료 ...
#   ... 3150개 매치 변환 완료 ...
#   ... 3200개 매치 변환 완료 ...
#   ... 3250개 매치 변환 완료 ...
#   ... 3300개 매치 변환 완료 ...
#   ... 3350개 매치 변환 완료 ...
#   ... 3400개 매치 변환 완료 ...
#   ... 3450개 매치 변환 완료 ...
#   ... 3500개 매치 변환 완료 ...
#   ... 3550개 매치 변환 완료 ...
#   ... 3600개 매치 변환 완료 ...
#   ... 3650개 매치 변환 완료 ...
#   ... 3700개 매치 변환 완료 ...
#   ... 3750개 매치 변환 완료 ...
#   ... 3800개 매치 변환 완료 ...
#   ... 3850개 매치 변환 완료 ...
#   ... 3900개 매치 변환 완료 ...
#   ... 3950개 매치 변환 완료 ...
#   ... 4000개 매치 변환 완료 ...
#   ... 4050개 매치 변환 완료 ...
#   ... 4100개 매치 변환 완료 ...
#   ... 4150개 매치 변환 완료 ...
#   ... 4200개 매치 변환 완료 ...
#   ... 4250개 매치 변환 완료 ...
#   ... 4300개 매치 변환 완료 ...
#   ... 4350개 매치 변환 완료 ...
#   ... 4400개 매치 변환 완료 ...
#   ... 4450개 매치 변환 완료 ...
#   ... 4500개 매치 변환 완료 ...
#   ... 4550개 매치 변환 완료 ...
#   ... 4600개 매치 변환 완료 ...
#   ... 4650개 매치 변환 완료 ...
#   ... 4700개 매치 변환 완료 ...
#   ... 4750개 매치 변환 완료 ...
#   ... 4800개 매치 변환 완료 ...
#   ... 4850개 매치 변환 완료 ...
#   ... 4900개 매치 변환 완료 ...
#   ... 4950개 매치 변환 완료 ...
#   ... 5000개 매치 변환 완료 ...
#   ... 5050개 매치 변환 완료 ...
#   ... 5100개 매치 변환 완료 ...
#   ... 5150개 매치 변환 완료 ...
#   ... 5200개 매치 변환 완료 ...
#   ... 5250개 매치 변환 완료 ...
#   ... 5300개 매치 변환 완료 ...
#   ... 5350개 매치 변환 완료 ...
#   ... 5400개 매치 변환 완료 ...
#   ... 5450개 매치 변환 완료 ...
#   ... 5500개 매치 변환 완료 ...
#   ... 5550개 매치 변환 완료 ...
#   ... 5600개 매치 변환 완료 ...
#   ... 5650개 매치 변환 완료 ...
#   - 성공! -> timeline_tr1_part1.csv 저장 완료
# ▶ 타임라인 파일 변환 중: timeline_tw2_part1.parquet
#   ... 50개 매치 변환 완료 ...
#   ... 100개 매치 변환 완료 ...
#   ... 150개 매치 변환 완료 ...
#   ... 200개 매치 변환 완료 ...
#   ... 250개 매치 변환 완료 ...
#   ... 300개 매치 변환 완료 ...
#   ... 350개 매치 변환 완료 ...
#   ... 400개 매치 변환 완료 ...
#   ... 450개 매치 변환 완료 ...
#   ... 500개 매치 변환 완료 ...
#   ... 550개 매치 변환 완료 ...
#   ... 600개 매치 변환 완료 ...
#   ... 650개 매치 변환 완료 ...
#   ... 700개 매치 변환 완료 ...
#   ... 750개 매치 변환 완료 ...
#   ... 800개 매치 변환 완료 ...
#   ... 850개 매치 변환 완료 ...
#   ... 900개 매치 변환 완료 ...
#   ... 950개 매치 변환 완료 ...
#   ... 1000개 매치 변환 완료 ...
#   ... 1050개 매치 변환 완료 ...
#   ... 1100개 매치 변환 완료 ...
#   ... 1150개 매치 변환 완료 ...
#   ... 1200개 매치 변환 완료 ...
#   ... 1250개 매치 변환 완료 ...
#   ... 1300개 매치 변환 완료 ...
#   ... 1350개 매치 변환 완료 ...
#   ... 1400개 매치 변환 완료 ...
#   ... 1450개 매치 변환 완료 ...
#   ... 1500개 매치 변환 완료 ...
#   - 성공! -> timeline_tw2_part1.csv 저장 완료
# ▶ 타임라인 파일 변환 중: timeline_vn2_part1.parquet
#   ... 50개 매치 변환 완료 ...
#   ... 100개 매치 변환 완료 ...
#   ... 150개 매치 변환 완료 ...
#   ... 200개 매치 변환 완료 ...
#   ... 250개 매치 변환 완료 ...
#   ... 300개 매치 변환 완료 ...
#   ... 350개 매치 변환 완료 ...
#   ... 400개 매치 변환 완료 ...
#   ... 450개 매치 변환 완료 ...
#   ... 500개 매치 변환 완료 ...
#   ... 550개 매치 변환 완료 ...
#   ... 600개 매치 변환 완료 ...
#   ... 650개 매치 변환 완료 ...
#   ... 700개 매치 변환 완료 ...
#   ... 750개 매치 변환 완료 ...
#   ... 800개 매치 변환 완료 ...
#   ... 850개 매치 변환 완료 ...
#   ... 900개 매치 변환 완료 ...
#   ... 950개 매치 변환 완료 ...
#   ... 1000개 매치 변환 완료 ...
#   ... 1050개 매치 변환 완료 ...
#   ... 1100개 매치 변환 완료 ...
#   ... 1150개 매치 변환 완료 ...
#   ... 1200개 매치 변환 완료 ...
#   ... 1250개 매치 변환 완료 ...
#   ... 1300개 매치 변환 완료 ...
#   ... 1350개 매치 변환 완료 ...
#   ... 1400개 매치 변환 완료 ...
#   ... 1450개 매치 변환 완료 ...
#   ... 1500개 매치 변환 완료 ...
#   ... 1550개 매치 변환 완료 ...
#   ... 1600개 매치 변환 완료 ...
#   ... 1650개 매치 변환 완료 ...
#   ... 1700개 매치 변환 완료 ...
#   ... 1750개 매치 변환 완료 ...
#   ... 1800개 매치 변환 완료 ...
#   ... 1850개 매치 변환 완료 ...
#   ... 1900개 매치 변환 완료 ...
#   ... 1950개 매치 변환 완료 ...
#   ... 2000개 매치 변환 완료 ...
#   ... 2050개 매치 변환 완료 ...
#   ... 2100개 매치 변환 완료 ...
#   ... 2150개 매치 변환 완료 ...
#   ... 2200개 매치 변환 완료 ...
#   ... 2250개 매치 변환 완료 ...
#   ... 2300개 매치 변환 완료 ...
#   - 실패! (사유: [Errno 28] No space left on device)
# ============================================================
# 모든 타임라인 변환 작업이 완료되었습니다!

# %%
import pandas as pd
import os
import glob

def batch_filter_timeline_columns_exclude_kr(folder_path):
    """
    지정된 폴더에서 'kr'을 제외한 모든 CSV 파일을 찾아,
    사용자가 지정한 컬럼(keep_keywords)만 추출한 뒤 원본 파일명 그대로 덮어쓰기 합니다.
    """
    if not os.path.exists(folder_path):
        print(f"오류: '{folder_path}' 폴더를 찾을 수 없습니다.")
        return

    # 1. 대상 폴더에서 모든 .csv 파일 검색
    search_pattern = os.path.join(folder_path, "*.csv")
    all_files = glob.glob(search_pattern)

    # 2. 'kr'이 포함된 파일 제외
    target_files = [f for f in all_files if 'kr' not in os.path.basename(f).lower()]

    if not target_files:
        print("조건에 맞는 처리할 대상 CSV 파일이 없습니다.")
        return

    print(f"총 {len(target_files)}개의 타임라인 파일 컬럼 필터링을 시작합니다. (kr 제외)\n")
    print("=" * 60)

    # 3. 추출할 필수 키워드 목록 (점 대신 밑줄 적용)
    keep_keywords = [
        "matchId", "minute", "timestamp", "events", "participantId",
        "totalGold", "level", "xp", "minionsKilled", "jungleMinionsKilled",
        "timeEnemySpentControlled", "damageStats_magicDamageDone",
        "damageStats_magicDamageDoneToChampions", "damageStats_magicDamageTaken",
        "damageStats_physicalDamageDone", "damageStats_physicalDamageDoneToChampions",
        "damageStats_physicalDamageTaken", "damageStats_totalDamageDone",
        "damageStats_totalDamageDoneToChampions", "damageStats_totalDamageTaken",
        "damageStats_trueDamageDone", "damageStats_trueDamageDoneToChampions",
        "damageStats_trueDamageTaken"
    ]

    # 4. 파일별 순회 및 필터링 시작
    for input_csv in target_files:
        file_name = os.path.basename(input_csv)
        
        # 덮어쓰기 전 데이터를 안전하게 담아둘 임시 파일
        temp_csv = input_csv + ".temp"

        try:
            print(f"▶ 필터링 시작: {file_name}")

            # 원본 파일의 컬럼(열) 구조 분석 (첫 0행만 읽기)
            actual_columns = pd.read_csv(input_csv, nrows=0).columns.tolist()
            
            # 남길 컬럼만 추려내기
            columns_to_keep = []
            for col in actual_columns:
                if any(keyword in col for keyword in keep_keywords):
                    columns_to_keep.append(col)

            if not columns_to_keep:
                print(f"  - [경고] 추출할 컬럼이 하나도 없습니다. 이 파일은 건너뜁니다.")
                continue

            print(f"  -> 총 {len(actual_columns)}개의 컬럼 중 {len(columns_to_keep)}개의 컬럼만 남깁니다.")

            # 메모리 절약을 위해 데이터를 10,000줄씩 잘라서 임시 파일에 저장
            is_first = True
            for chunk in pd.read_csv(input_csv, usecols=columns_to_keep, chunksize=10000, low_memory=False):
                if is_first:
                    chunk.to_csv(temp_csv, mode='w', index=False, encoding='utf-8-sig')
                    is_first = False
                else:
                    chunk.to_csv(temp_csv, mode='a', header=False, index=False, encoding='utf-8-sig')

            # 변환이 완벽하게 끝났으면, 임시 파일을 원본 파일 이름으로 덮어쓰기
            os.replace(temp_csv, input_csv)
            
            print(f"  - 성공! 기존 파일 덮어쓰기 완료\n")

        except Exception as e:
            print(f"  - 실패! (사유: {e})\n")
            # 에러가 났을 경우 찌꺼기 임시 파일 삭제
            if os.path.exists(temp_csv):
                os.remove(temp_csv)

    print("=" * 60)
    print("모든 타임라인 파일의 컬럼 추출 및 덮어쓰기 작업이 완료되었습니다!")


# ==========================================
# 실행을 위한 파일 경로 설정
# ==========================================

# 지정해주신 타임라인 폴더 경로
folder_path = r"D:\바탕화면\데이터 분석\프로젝트\04 최종 프로젝트\구글 드라이브\timeline"

# 함수 실행
batch_filter_timeline_columns_exclude_kr(folder_path)
# Out:
# 총 15개의 타임라인 파일 컬럼 필터링을 시작합니다. (kr 제외)
#
# ============================================================
# ▶ 필터링 시작: timeline_br1_part1.csv
#   - [경고] 추출할 컬럼이 하나도 없습니다. 이 파일은 건너뜁니다.
# ▶ 필터링 시작: timeline_eun1_part1.csv
#   - [경고] 추출할 컬럼이 하나도 없습니다. 이 파일은 건너뜁니다.
# ▶ 필터링 시작: timeline_euw1_part1.csv
#   - [경고] 추출할 컬럼이 하나도 없습니다. 이 파일은 건너뜁니다.
# ▶ 필터링 시작: timeline_euw1_part2.csv
#   - [경고] 추출할 컬럼이 하나도 없습니다. 이 파일은 건너뜁니다.
# ▶ 필터링 시작: timeline_euw1_part3.csv
#   - [경고] 추출할 컬럼이 하나도 없습니다. 이 파일은 건너뜁니다.
# ▶ 필터링 시작: timeline_jp1_part1.csv
#   - [경고] 추출할 컬럼이 하나도 없습니다. 이 파일은 건너뜁니다.
# ▶ 필터링 시작: timeline_la1_part1.csv
#   - [경고] 추출할 컬럼이 하나도 없습니다. 이 파일은 건너뜁니다.
# ▶ 필터링 시작: timeline_la2_part1.csv
#   - [경고] 추출할 컬럼이 하나도 없습니다. 이 파일은 건너뜁니다.
# ▶ 필터링 시작: timeline_me1_part1.csv
#   - [경고] 추출할 컬럼이 하나도 없습니다. 이 파일은 건너뜁니다.
# ▶ 필터링 시작: timeline_na1_part1.csv
#   - [경고] 추출할 컬럼이 하나도 없습니다. 이 파일은 건너뜁니다.
# ▶ 필터링 시작: timeline_oc1_part1.csv
#   - [경고] 추출할 컬럼이 하나도 없습니다. 이 파일은 건너뜁니다.
# ▶ 필터링 시작: timeline_ru_part1.csv
#   - [경고] 추출할 컬럼이 하나도 없습니다. 이 파일은 건너뜁니다.
# ▶ 필터링 시작: timeline_sg2_part1.csv
#   - [경고] 추출할 컬럼이 하나도 없습니다. 이 파일은 건너뜁니다.
# ▶ 필터링 시작: timeline_tr1_part1.csv
#   - [경고] 추출할 컬럼이 하나도 없습니다. 이 파일은 건너뜁니다.
# ▶ 필터링 시작: timeline_tw2_part1.csv
#   - [경고] 추출할 컬럼이 하나도 없습니다. 이 파일은 건너뜁니다.
# ============================================================
# 모든 타임라인 파일의 컬럼 추출 및 덮어쓰기 작업이 완료되었습니다!

# %%
import pandas as pd
import os

def filter_single_timeline_file(file_path):
    """
    지정된 단일 타임라인 CSV 파일에서 필요한 컬럼만 추출한 뒤,
    원본 파일명 그대로 안전하게 덮어쓰기 합니다.
    """
    if not os.path.exists(file_path):
        print(f"오류: '{file_path}' 파일을 찾을 수 없습니다. 경로를 확인해주세요.")
        return

    print(f"============================================================")
    print(f"▶ 단일 파일 필터링 시작: {os.path.basename(file_path)}")
    print(f"============================================================")

    # 추출할 필수 키워드 목록
    keep_keywords = [
        "matchId", "minute", "timestamp", "events", "participantId",
        "totalGold", "level", "xp", "minionsKilled", "jungleMinionsKilled",
        "timeEnemySpentControlled", "damageStats_magicDamageDone",
        "damageStats_magicDamageDoneToChampions", "damageStats_magicDamageTaken",
        "damageStats_physicalDamageDone", "damageStats_physicalDamageDoneToChampions",
        "damageStats_physicalDamageTaken", "damageStats_totalDamageDone",
        "damageStats_totalDamageDoneToChampions", "damageStats_totalDamageTaken",
        "damageStats_trueDamageDone", "damageStats_trueDamageDoneToChampions",
        "damageStats_trueDamageTaken"
    ]

    # 임시 파일 경로 설정
    temp_csv = file_path + ".temp"

    try:
        # 1. 원본 파일의 컬럼(열) 구조 분석 (첫 0행만 읽기)
        actual_columns = pd.read_csv(file_path, nrows=0).columns.tolist()
        
        # 2. 남길 컬럼만 추려내기
        columns_to_keep = []
        for col in actual_columns:
            if any(keyword in col for keyword in keep_keywords):
                columns_to_keep.append(col)

        if not columns_to_keep:
            print(f"  - [경고] 추출할 컬럼이 하나도 없습니다. 파일 구조를 확인해주세요.")
            return

        print(f"  -> 총 {len(actual_columns)}개의 컬럼 중 {len(columns_to_keep)}개의 컬럼만 남깁니다.")

        # 3. 메모리 절약을 위해 데이터를 10,000줄씩 잘라서 임시 파일에 저장
        is_first = True
        for chunk in pd.read_csv(file_path, usecols=columns_to_keep, chunksize=10000, low_memory=False):
            if is_first:
                chunk.to_csv(temp_csv, mode='w', index=False, encoding='utf-8-sig')
                is_first = False
            else:
                chunk.to_csv(temp_csv, mode='a', header=False, index=False, encoding='utf-8-sig')

        # 4. 변환이 완벽하게 끝났으면, 임시 파일을 원본 파일 이름으로 덮어쓰기
        os.replace(temp_csv, file_path)
        
        print(f"  - 성공! 기존 파일 덮어쓰기가 완료되었습니다.\n")

    except Exception as e:
        print(f"  - 실패! (사유: {e})\n")
        # 에러가 났을 경우 찌꺼기 임시 파일 삭제
        if os.path.exists(temp_csv):
            os.remove(temp_csv)


# ==========================================
# 실행을 위한 파일 경로 설정
# ==========================================

# 요청하신 특정 파일의 절대 경로
target_file_path = r"D:\바탕화면\데이터 분석\프로젝트\04 최종 프로젝트\구글 드라이브\timeline\timeline_br1_part1.csv"

# 함수 실행
filter_single_timeline_file(target_file_path)
# Out:
# ============================================================
# ▶ 단일 파일 필터링 시작: timeline_br1_part1.csv
# ============================================================
#   - [경고] 추출할 컬럼이 하나도 없습니다. 파일 구조를 확인해주세요.
